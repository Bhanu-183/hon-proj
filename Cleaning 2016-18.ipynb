# %%
import pandas as pd

# %%
df=pd.read_csv("2016.csv")

# %%
df.columns
# Out:
# Index(['S. No. (Col.1)', 'State/UT (Col.2)',
#        'Offences affecting the Human Body - Murder (Sec 302 IPC) - I (Col.3)',
#        'Offences affecting the Human Body - Murder (Sec 302 IPC) - V (Col.4)',
#        'Offences affecting the Human Body - Murder (Sec 302 IPC) - R (Col.5)',
#        'Offences affecting the Human Body - Culpable Homicide Not Amounting To Murder (Sec 304 IPC) - I (Col.6)',
#        'Offences affecting the Human Body - Culpable Homicide Not Amounting To Murder (Sec 304 IPC) - V (Col.7)',
#        'Offences affecting the Human Body - Culpable Homicide Not Amounting To Murder (Sec 304 IPC) - R (Col.8)',
#        'Offences affecting the Human Body - Causing Death By Negligence - Causing Death By Negligence (Total) (Sec 304A IPC) - I (Col.9)',
#        'Offences affecting the Human Body - Causing Death By Negligence - Causing Death By Negligence (Total) (Sec 304A IPC) - V (Col.10)',
#        ...
# ...

# %% [markdown]
# ## Since there many other crimes like theft,murder,homicide etc,I have picked the crimes on women which are very serious offences
#
# ### 1. Rape
# ### 2. Dowry Deaths
# ### 3. Assault on women with intent to outrage her modesty
# ### 4. Cruelty By Husband or his relatives
# ### 5. Insult to the modesty of women
# ### 6. Kidnapping and Abduction

# %%
new_df=df.filter(['State/UT (Col.2)',"Offences affecting the Human Body - Rape - Rape (Total) - I (Col.36)","Offences affecting the Human Body - Dowry Deaths* (Sec 304B IPC) - I (Col.12)","Offences affecting the Human Body - Assault on Women With intent to Outrage her Modesty - Assault On Women With Intent To Outrage Her Modesty (Total) - I (Col.27)","Miscellaneous - Cruelty By Husband or His Relatives (Sec 498A IPC) - I (Col.107)","Miscellaneous - Insult to the Modesty of Women (Sec 509 IPC) - I (Col.110)",'Offences affecting the Human Body - Kidnapping & Abduction - Kidnapping & Abduction (Total) - I (Col.30)'],axis=1)

# %%
new_df
# Out:
#      State/UT (Col.2)  \
# 0      Andhra Pradesh
# 1   Arunachal Pradesh
# 2               Assam
# 3               Bihar
# 4        Chhattisgarh
# 5                 Goa
# 6             Gujarat
# 7             Haryana
# 8    Himachal Pradesh
# 9     Jammu & Kashmir
# 10          Jharkhand
# 11          Karnataka
# 12             Kerala
# 13     Madhya Pradesh
# 14        Maharashtra
# 15            Manipur
# 16          Meghalaya
# 17            Mizoram
# 18           Nagaland
# 19             Odisha
# 20             Punjab
# 21          Rajasthan
# 22             Sikkim
# 23         Tamil Nadu
# 24          Telangana
# 25            Tripura
# 26      Uttar Pradesh
# 27        Uttarakhand
# 28        West Bengal
# 29     Total (States)
# 30      A & N Islands
# 31         Chandigarh
# 32         D&N Haveli
# 33        Daman & Diu
# 34              Delhi
# 35        Lakshadweep
# 36         Puducherry
# 37        Total (UTs)
# 38  Total (All-India)
#
# ...

# %% [markdown]
# ### Renaming the selected columns and setting the index

# %%
new_df.rename(columns={'Offences affecting the Human Body - Kidnapping & Abduction - Kidnapping & Abduction (Total) - I (Col.30)':'Kidnapping and Abduction','Miscellaneous - Insult to the Modesty of Women (Sec 509 IPC) - I (Col.110)':"Insult to the modesty of women","Miscellaneous - Cruelty By Husband or His Relatives (Sec 498A IPC) - I (Col.107)":'Cruelty By Husband or his relatives','Offences affecting the Human Body - Assault on Women With intent to Outrage her Modesty - Assault On Women With Intent To Outrage Her Modesty (Total) - I (Col.27)':'Assault on women with intent to outrage her modesty','Offences affecting the Human Body - Dowry Deaths* (Sec 304B IPC) - I (Col.12)':'Dowry Deaths','State/UT (Col.2)':'ST','Offences affecting the Human Body - Rape - Rape (Total) - I (Col.36)':'Rape'},inplace=True)
new_df.reindex()
# Out:
#                    ST   Rape  Dowry Deaths  \
# 0      Andhra Pradesh    994           193
# 1   Arunachal Pradesh     92             1
# 2               Assam   1779           157
# 3               Bihar   1008           987
# 4        Chhattisgarh   1626            84
# 5                 Goa     61             2
# 6             Gujarat    982            12
# 7             Haryana   1187           260
# 8    Himachal Pradesh    252             3
# 9     Jammu & Kashmir    256             6
# 10          Jharkhand   1109           278
# 11          Karnataka   1655           234
# 12             Kerala   1656            25
# 13     Madhya Pradesh   4882           629
# 14        Maharashtra   4189           248
# 15            Manipur     55             0
# 16          Meghalaya    190             0
# 17            Mizoram     23             0
# 18           Nagaland     26             1
# 19             Odisha   1983           397
# 20             Punjab    838            80
# ...

# %%
new_df.head(10)
# Out:
#                   ST  Rape  Dowry Deaths  \
# 0     Andhra Pradesh   994           193
# 1  Arunachal Pradesh    92             1
# 2              Assam  1779           157
# 3              Bihar  1008           987
# 4       Chhattisgarh  1626            84
# 5                Goa    61             2
# 6            Gujarat   982            12
# 7            Haryana  1187           260
# 8   Himachal Pradesh   252             3
# 9    Jammu & Kashmir   256             6
#
#    Assault on women with intent to outrage her modesty  \
# 0                                               4829
# 1                                                109
# 2                                               3378
# 3                                                324
# 4                                               1770
# 5                                                143
# 6                                               1224
# 7                                               1860
# ...

# %%
new_df.set_index('ST',inplace=True)

# %%
new_df.sample(5)
# Out:
#             Rape  Dowry Deaths  \
# ST
# Haryana     1187           260
# Gujarat      982            12
# Tamil Nadu   319            58
# Karnataka   1655           234
# Mizoram       23             0
#
#             Assault on women with intent to outrage her modesty  \
# ST
# Haryana                                                  1860
# Gujarat                                                  1224
# Tamil Nadu                                                854
# Karnataka                                                5260
# Mizoram                                                    71
#
#             Cruelty By Husband or his relatives  \
# ST
# Haryana                                    3313
# Gujarat                                    3732
# Tamil Nadu                                 1256
# Karnataka                                  2556
# Mizoram                                      19
#
#             Insult to the modesty of women  Kidnapping and Abduction
# ST
# ...

# %%
new_df.drop(['Total (All-India)','Total (States)'],inplace=True)

# %%
new_df
# Out:
#                    Rape  Dowry Deaths  \
# ST
# Andhra Pradesh      994           193
# Arunachal Pradesh    92             1
# Assam              1779           157
# Bihar              1008           987
# Chhattisgarh       1626            84
# Goa                  61             2
# Gujarat             982            12
# Haryana            1187           260
# Himachal Pradesh    252             3
# Jammu & Kashmir     256             6
# Jharkhand          1109           278
# Karnataka          1655           234
# Kerala             1656            25
# Madhya Pradesh     4882           629
# Maharashtra        4189           248
# Manipur              55             0
# Meghalaya           190             0
# Mizoram              23             0
# Nagaland             26             1
# Odisha             1983           397
# Punjab              838            80
# Rajasthan          3656           462
# Sikkim               92             0
# ...

# %%
new_df.rename(columns={'Rape':'Rape 16','Dowry Deaths':'Dowry Deaths 16','Assault on women with intent to outrage her modesty':'Assault on women with intent to outrage her modesty 16','Cruelty By Husband or his relatives':'Cruelty By Husband or his relatives 16','Insult to the modesty of women':'Insult to the modesty of women 16','Kidnapping and Abduction':'Kidnapping and Abduction 16'},inplace=True)

# %%
new_df.head(5)
# Out:
#                    Rape 16  Dowry Deaths 16  \
# ST
# Andhra Pradesh         994              193
# Arunachal Pradesh       92                1
# Assam                 1779              157
# Bihar                 1008              987
# Chhattisgarh          1626               84
#
#                    Assault on women with intent to outrage her modesty 16  \
# ST
# Andhra Pradesh                                                  4829
# Arunachal Pradesh                                                109
# Assam                                                           3378
# Bihar                                                            324
# Chhattisgarh                                                    1770
#
#                    Cruelty By Husband or his relatives 16  \
# ST
# Andhra Pradesh                                       6461
# Arunachal Pradesh                                      50
# Assam                                                9321
# ...

# %%
df_17=pd.read_csv("2017.csv")

# %%
df_17.head(10)
# Out:
#   S. No (Col.1) Category (Col.2)   State/UT (Col.3)  \
# 0             1            State     Andhra Pradesh
# 1             2            State  Arunachal Pradesh
# 2             3            State              Assam
# 3             4            State              Bihar
# 4             5            State       Chhattisgarh
# 5             6            State                Goa
# 6             7            State            Gujarat
# 7             8            State            Haryana
# 8             9            State   Himachal Pradesh
# 9            10            State    Jammu & Kashmir
#
#    Offences affecting the Human Body - Murder (Sec.302 IPC) - I (Col.4)  \
# 0                                               1054
# 1                                                 79
# 2                                               1144
# 3                                               2803
# 4                                                919
# ...

# %%
temp_df=df_17.filter(['State/UT (Col.3)','Offences affecting the Human Body - Rape (Sec.376 IPC) - I (Col.175)','Offences affecting the Human Body - Attempt to Commit Rape (Sec.376/511 IPC) - I (Col.178)','Offences affecting the Human Body - Dowry Deaths (Sec.304-B IPC) - I (Col.34)','Offences affecting the Human Body - Assault on Women with Intent to Outrage her Modesty - Sec.354 IPC (Total) - I (Col.100)','Miscellaneous IPC Crimes - Cruelty by Husband or his Relatives (Sec.498-A IPC) - I (Col.408)','Miscellaneous IPC Crimes - Insult to the Modesty of Women (Sec.509 IPC) - I (Col.417)','Offences affecting the Human Body - Kidnapping and Abduction - Total - I (Col.130)'],axis=1)

# %%
temp_df
# Out:
#      State/UT (Col.3)  \
# 0      Andhra Pradesh
# 1   Arunachal Pradesh
# 2               Assam
# 3               Bihar
# 4        Chhattisgarh
# 5                 Goa
# 6             Gujarat
# 7             Haryana
# 8    Himachal Pradesh
# 9     Jammu & Kashmir
# 10          Jharkhand
# 11          Karnataka
# 12             Kerala
# 13     Madhya Pradesh
# 14        Maharashtra
# 15            Manipur
# 16          Meghalaya
# 17            Mizoram
# 18           Nagaland
# 19             Odisha
# 20             Punjab
# 21          Rajasthan
# 22             Sikkim
# 23         Tamil Nadu
# 24          Telangana
# 25            Tripura
# 26      Uttar Pradesh
# 27        Uttarakhand
# 28        West Bengal
# 29     Total State(S)
# 30        A&N Islands
# 31         Chandigarh
# 32         D&N Haveli
# 33        Daman & Diu
# 34              Delhi
# 35        Lakshadweep
# 36         Puducherry
# 37        Total UT(S)
# 38    Total All India
#
# ...

# %%
temp_df['Rape 17']=temp_df['Offences affecting the Human Body - Rape (Sec.376 IPC) - I (Col.175)']+temp_df['Offences affecting the Human Body - Attempt to Commit Rape (Sec.376/511 IPC) - I (Col.178)']

# %%
temp_df.drop(columns=['Offences affecting the Human Body - Rape (Sec.376 IPC) - I (Col.175)','Offences affecting the Human Body - Attempt to Commit Rape (Sec.376/511 IPC) - I (Col.178)'],inplace=True)

# %% [markdown]
# ##### temp_df.sample(3)

# %%
temp_df.rename(columns={'Offences affecting the Human Body - Dowry Deaths (Sec.304-B IPC) - I (Col.34)':'Dowry Deaths 17','Offences affecting the Human Body - Assault on Women with Intent to Outrage her Modesty - Sec.354 IPC (Total) - I (Col.100)':'Assault on women with intent to outrage her modesty 17','Miscellaneous IPC Crimes - Cruelty by Husband or his Relatives (Sec.498-A IPC) - I (Col.408)':'Cruelty By Husband or his relatives 17','Miscellaneous IPC Crimes - Insult to the Modesty of Women (Sec.509 IPC) - I (Col.417)':'Insult to the modesty of women 17','Offences affecting the Human Body - Kidnapping and Abduction - Total - I (Col.130)':'Kidnapping and Abduction'},inplace=True)

# %%
temp_df
# Out:
#      State/UT (Col.3)  Dowry Deaths 17  \
# 0      Andhra Pradesh              152
# 1   Arunachal Pradesh                0
# 2               Assam              171
# 3               Bihar             1081
# 4        Chhattisgarh               74
# 5                 Goa                1
# 6             Gujarat                9
# 7             Haryana              245
# 8    Himachal Pradesh                3
# 9     Jammu & Kashmir                8
# 10          Jharkhand              248
# 11          Karnataka              206
# 12             Kerala               12
# 13     Madhya Pradesh              632
# 14        Maharashtra              233
# 15            Manipur                0
# 16          Meghalaya                1
# 17            Mizoram                0
# 18           Nagaland                0
# 19             Odisha              326
# 20             Punjab               68
# 21          Rajasthan              457
# 22             Sikkim                0
# ...

# %%
new_df
# Out:
#                    Rape 16  Dowry Deaths 16  \
# ST
# Andhra Pradesh         994              193
# Arunachal Pradesh       92                1
# Assam                 1779              157
# Bihar                 1008              987
# Chhattisgarh          1626               84
# Goa                     61                2
# Gujarat                982               12
# Haryana               1187              260
# Himachal Pradesh       252                3
# Jammu & Kashmir        256                6
# Jharkhand             1109              278
# Karnataka             1655              234
# Kerala                1656               25
# Madhya Pradesh        4882              629
# Maharashtra           4189              248
# Manipur                 55                0
# Meghalaya              190                0
# Mizoram                 23                0
# Nagaland                26                1
# Odisha                1983              397
# ...

# %%
temp_df.drop(['Total (UTs)'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_23847/2576462286.py in <module>
# ----> 1 temp_df.drop(['Total (UTs)'],inplace=True)
#
# ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4946                 weight  1.0     0.8
#    4947         """
# -> 4948         return super().drop(
#    4949             labels=labels,
#    4950             axis=axis,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
temp_df
# Out:
#      State/UT (Col.3)  Dowry Deaths 17  \
# 0      Andhra Pradesh              152
# 1   Arunachal Pradesh                0
# 2               Assam              171
# 3               Bihar             1081
# 4        Chhattisgarh               74
# 5                 Goa                1
# 6             Gujarat                9
# 7             Haryana              245
# 8    Himachal Pradesh                3
# 9     Jammu & Kashmir                8
# 10          Jharkhand              248
# 11          Karnataka              206
# 12             Kerala               12
# 13     Madhya Pradesh              632
# 14        Maharashtra              233
# 15            Manipur                0
# 16          Meghalaya                1
# 17            Mizoram                0
# 18           Nagaland                0
# 19             Odisha              326
# 20             Punjab               68
# 21          Rajasthan              457
# 22             Sikkim                0
# ...

# %%
temp_df.set_index(['State/UT (Col.3)'],inplace=True)

# %%
temp_df.drop(['Total All India','Total State(S)'],inplace=True)

# %%
temp_df.rename(columns={'A&N Islands':'A & N Islands'},inplace=True)

# %%
new_df
# Out:
#                    Rape 16  Dowry Deaths 16  \
# ST
# Andhra Pradesh         994              193
# Arunachal Pradesh       92                1
# Assam                 1779              157
# Bihar                 1008              987
# Chhattisgarh          1626               84
# Goa                     61                2
# Gujarat                982               12
# Haryana               1187              260
# Himachal Pradesh       252                3
# Jammu & Kashmir        256                6
# Jharkhand             1109              278
# Karnataka             1655              234
# Kerala                1656               25
# Madhya Pradesh        4882              629
# Maharashtra           4189              248
# Manipur                 55                0
# Meghalaya              190                0
# Mizoram                 23                0
# Nagaland                26                1
# Odisha                1983              397
# ...

# %%
new_df.drop(['Total (UTs)'],inplace=True)

# %%
new_df['Rape 17']=temp_df['Rape 17']
new_df.at['A & N Islands','Rape 17']=13
new_df['Rape 17']=new_df['Rape 17'].astype(int)

# %%
new_df
# Out:
#                    Rape 16  Dowry Deaths 16  \
# ST
# Andhra Pradesh         994              193
# Arunachal Pradesh       92                1
# Assam                 1779              157
# Bihar                 1008              987
# Chhattisgarh          1626               84
# Goa                     61                2
# Gujarat                982               12
# Haryana               1187              260
# Himachal Pradesh       252                3
# Jammu & Kashmir        256                6
# Jharkhand             1109              278
# Karnataka             1655              234
# Kerala                1656               25
# Madhya Pradesh        4882              629
# Maharashtra           4189              248
# Manipur                 55                0
# Meghalaya              190                0
# Mizoram                 23                0
# Nagaland                26                1
# Odisha                1983              397
# ...

# %%
new_df.sample()
# Out:
#             Rape 16  Dowry Deaths 16  \
# ST
# Chandigarh       68                4
#
#             Assault on women with intent to outrage her modesty 16  \
# ST
# Chandigarh                                                 76
#
#             Cruelty By Husband or his relatives 16  \
# ST
# Chandigarh                                     122
#
#             Insult to the modesty of women 16  Kidnapping and Abduction 16  \
# ST
# Chandigarh                                 13                          180
#
#             Rape 17
# ST
# Chandigarh       68

# %%
temp_df.loc[['A&N Islands']]
# Out:
#                   Dowry Deaths 17  \
# State/UT (Col.3)
# A&N Islands                     1
#
#                   Assault on women with intent to outrage her modesty 17  \
# State/UT (Col.3)
# A&N Islands                                                      38
#
#                   Cruelty By Husband or his relatives 17  \
# State/UT (Col.3)
# A&N Islands                                            4
#
#                   Insult to the modesty of women 17  Kidnapping and Abduction  \
# State/UT (Col.3)
# A&N Islands                                      11                        34
#
#                   Rape 17
# State/UT (Col.3)
# A&N Islands            13

# %%
new_df['Dowry Deaths 17']=temp_df['Dowry Deaths 17']
new_df['Assault on women with intent to outrage her modesty 17']=temp_df['Assault on women with intent to outrage her modesty 17']
new_df['Cruelty By Husband or his relatives 17']=temp_df['Cruelty By Husband or his relatives 17']
new_df['Insult to the modesty of women 17']=temp_df['Insult to the modesty of women 17']
new_df['Kidnapping and Abduction 17']=temp_df['Kidnapping and Abduction']

# %%
new_df.at['A & N Islands','Dowry Deaths 17']=1
new_df.at['A & N Islands','Assault on women with intent to outrage her modesty 17']=38
new_df.at['A & N Islands','Cruelty By Husband or his relatives 17']=4
new_df.at['A & N Islands','Insult to the modesty of women 17']=11
new_df.at['A & N Islands','Kidnapping and Abduction 17']=34

new_df[['Assault on women with intent to outrage her modesty 17','Insult to the modesty of women 17','Dowry Deaths 17','Kidnapping and Abduction 17','Cruelty By Husband or his relatives 17']]=new_df[['Assault on women with intent to outrage her modesty 17','Insult to the modesty of women 17','Dowry Deaths 17','Kidnapping and Abduction 17','Cruelty By Husband or his relatives 17']].astype(int)

# %%
new_df
# Out:
#                    Rape 16  Dowry Deaths 16  \
# ST
# Andhra Pradesh         994              193
# Arunachal Pradesh       92                1
# Assam                 1779              157
# Bihar                 1008              987
# Chhattisgarh          1626               84
# Goa                     61                2
# Gujarat                982               12
# Haryana               1187              260
# Himachal Pradesh       252                3
# Jammu & Kashmir        256                6
# Jharkhand             1109              278
# Karnataka             1655              234
# Kerala                1656               25
# Madhya Pradesh        4882              629
# Maharashtra           4189              248
# Manipur                 55                0
# Meghalaya              190                0
# Mizoram                 23                0
# Nagaland                26                1
# Odisha                1983              397
# ...

# %% [markdown]
# ## Added 2017 data to the dataframe

# %%
new_df.sample(5)
# Out:
#                 Rape 16  Dowry Deaths 16  \
# ST
# Madhya Pradesh     4882              629
# West Bengal        1110              535
# Uttar Pradesh      4816             2473
# Chhattisgarh       1626               84
# Rajasthan          3656              462
#
#                 Assault on women with intent to outrage her modesty 16  \
# ST
# Madhya Pradesh                                               8717
# West Bengal                                                  4177
# Uttar Pradesh                                               11335
# Chhattisgarh                                                 1770
# Rajasthan                                                    4839
#
#                 Cruelty By Husband or his relatives 16  \
# ST
# Madhya Pradesh                                    6264
# West Bengal                                      19302
# Uttar Pradesh                                    11156
# Chhattisgarh                                       622
# ...

# %% [markdown]
# ### Adding 2018 data

# %%
l_df=pd.read_csv("2018.csv")

# %%
l_df.columns
# Out:
# Index(['S. No (Col.1)', 'Category (Col.2)', 'State/UT (Col.3)',
#        'Offences affecting the Human Body - Dowry Deaths (Sec.304-B IPC) - I (Col.34)',
#        'Offences affecting the Human Body - Dowry Deaths (Sec.304-B IPC) - V (Col.35)',
#        'Offences affecting the Human Body - Dowry Deaths (Sec.304-B IPC) - R (Col.36)',
#        'Offences affecting the Human Body - Abetment of Suicide (Sec.305/306 IPC) - I (Col.37)',
#        'Offences affecting the Human Body - Abetment of Suicide (Sec.305/306 IPC) - V (Col.38)',
#        'Offences affecting the Human Body - Abetment of Suicide (Sec.305/306 IPC) - R (Col.39)',
#        'Offences affecting the Human Body - Attempt to Commit Murder (Sec.307 IPC) - I (Col.40)',
#        'Offences affecting the Human Body - Attempt to Commit Murder (Sec.307 IPC) - V (Col.41)',
#        'Offences affecting the Human Body - Attempt to Commit Murder (Sec.307 IPC) - R (Col.42)',
# ...

# %%
df_18=l_df.filter(['State/UT (Col.3)','Offences affecting the Human Body - Rape (Sec.376 IPC) - I (Col.175)','Offences affecting the Human Body - Attempt to Commit Rape (Sec.376/511 IPC) - I (Col.178)','Offences affecting the Human Body - Dowry Deaths (Sec.304-B IPC) - I (Col.34)','Offences affecting the Human Body - Assault on Women with Intent to Outrage her Modesty (Sec.354 IPC) - Total - I (Col.100)','Miscellaneous IPC Crimes - Cruelty by Husband or his Relatives (Sec.498-A IPC) - I (Col.408)','Miscellaneous IPC Crimes - Insult to the Modesty of Women (Sec.509 IPC) - I (Col.417)','Offences affecting the Human Body - Kidnapping and Abduction - Sec.363 IPC - I (Col.133)'],axis=1)

# %%
df_18.head(10)
# Out:
#     State/UT (Col.3)  \
# 0     Andhra Pradesh
# 1  Arunachal Pradesh
# 2              Assam
# 3              Bihar
# 4       Chhattisgarh
# 5                Goa
# 6            Gujarat
# 7            Haryana
# 8   Himachal Pradesh
# 9    Jammu & Kashmir
#
#    Offences affecting the Human Body - Rape (Sec.376 IPC) - I (Col.175)  \
# 0                                                971
# 1                                                 67
# 2                                               1648
# 3                                                651
# 4                                               2091
# 5                                                 61
# 6                                                553
# 7                                               1296
# 8                                                344
# 9                                                320
#
#    Offences affecting the Human Body - Attempt to Commit Rape (Sec.376/511 IPC) - I (Col.178)  \
# ...

# %%
df_18['Rape 18']=df_18['Offences affecting the Human Body - Rape (Sec.376 IPC) - I (Col.175)']+df_18['Offences affecting the Human Body - Attempt to Commit Rape (Sec.376/511 IPC) - I (Col.178)']

# %%
df_18.rename(columns={'State/UT (Col.3)':'ST','Offences affecting the Human Body - Dowry Deaths (Sec.304-B IPC) - I (Col.34)':'Dowry Deaths 18','Offences affecting the Human Body - Assault on Women with Intent to Outrage her Modesty (Sec.354 IPC) - Total - I (Col.100)':'Assault on women with intent to outrage her modesty 18','Miscellaneous IPC Crimes - Cruelty by Husband or his Relatives (Sec.498-A IPC) - I (Col.408)':'Cruelty by Husband or his Relatives 18','Miscellaneous IPC Crimes - Insult to the Modesty of Women (Sec.509 IPC) - I (Col.417)':'Insult to the Modesty of Women 18','Offences affecting the Human Body - Kidnapping and Abduction - Sec.363 IPC - I (Col.133)':'Kidnapping and Abduction 18'},inplace=True)

# %%
df_18.sample(5)
# Out:
#                   ST  \
# 1  Arunachal Pradesh
# 7            Haryana
# 4       Chhattisgarh
# 9    Jammu & Kashmir
# 5                Goa
#
#    Offences affecting the Human Body - Rape (Sec.376 IPC) - I (Col.175)  \
# 1                                                 67
# 7                                               1296
# 4                                               2091
# 9                                                320
# 5                                                 61
#
#    Offences affecting the Human Body - Attempt to Commit Rape (Sec.376/511 IPC) - I (Col.178)  \
# 1                                                 11
# 7                                                176
# 4                                                 27
# 9                                                 23
# 5                                                  0
#
#    Dowry Deaths 18  Assault on women with intent to outrage her modesty 18  \
# ...

# %%
df_18.drop(columns=['Offences affecting the Human Body - Rape (Sec.376 IPC) - I (Col.175)','Offences affecting the Human Body - Attempt to Commit Rape (Sec.376/511 IPC) - I (Col.178)'],inplace=True)

# %%
df_18.set_index(['ST'],inplace=True)

# %%
df_18
# Out:
#                    Dowry Deaths 18  \
# ST
# Andhra Pradesh                 140
# Arunachal Pradesh                0
# Assam                          173
# Bihar                         1107
# Chhattisgarh                    79
# Goa                              0
# Gujarat                          9
# Haryana                        216
# Himachal Pradesh                 4
# Jammu & Kashmir                  8
# Jharkhand                      252
# Karnataka                      200
# Kerala                          17
# Madhya Pradesh                 547
# Maharashtra                    200
# Manipur                          0
# Meghalaya                        1
# Mizoram                          0
# Nagaland                         0
# Odisha                         372
# Punjab                          67
# Rajasthan                      404
# Sikkim                           1
# Tamil Nadu                      55
# Telangana                      186
# ...

# %%
new_df['Rape 18']=df_18['Rape 18']

# %%
new_df
# Out:
#                    Rape 16  Dowry Deaths 16  \
# ST
# Andhra Pradesh         994              193
# Arunachal Pradesh       92                1
# Assam                 1779              157
# Bihar                 1008              987
# Chhattisgarh          1626               84
# Goa                     61                2
# Gujarat                982               12
# Haryana               1187              260
# Himachal Pradesh       252                3
# Jammu & Kashmir        256                6
# Jharkhand             1109              278
# Karnataka             1655              234
# Kerala                1656               25
# Madhya Pradesh        4882              629
# Maharashtra           4189              248
# Manipur                 55                0
# Meghalaya              190                0
# Mizoram                 23                0
# Nagaland                26                1
# Odisha                1983              397
# ...

# %%
new_df['Dowry Deaths 18']=df_18['Dowry Deaths 18']
new_df['Assault on women with intent to outrage her modesty 18']=df_18['Assault on women with intent to outrage her modesty 18']
new_df['Cruelty by Husband or his Relatives 18']=df_18['Cruelty by Husband or his Relatives 18']
new_df['Insult to the Modesty of Women 18']=df_18['Insult to the Modesty of Women 18']
new_df['Kidnapping and Abduction 18']=df_18['Kidnapping and Abduction 18']

# %%
new_df.at['A & N Islands','Dowry Deaths 18']=0
new_df.at['A & N Islands','Assault on women with intent to outrage her modesty 18']=35
new_df.at['A & N Islands','Cruelty by Husband or his Relatives 18']=4
new_df.at['A & N Islands','Insult to the Modesty of Women 18']=4
new_df.at['A & N Islands','Kidnapping and Abduction 18']=33
new_df.at['A & N Islands','Rape 18']=30

new_df[['Dowry Deaths 18','Assault on women with intent to outrage her modesty 18','Cruelty by Husband or his Relatives 18','Insult to the Modesty of Women 18','Kidnapping and Abduction 18','Rape 18']]=new_df[['Dowry Deaths 18','Assault on women with intent to outrage her modesty 18','Cruelty by Husband or his Relatives 18','Insult to the Modesty of Women 18','Kidnapping and Abduction 18','Rape 18']].astype(int)

# %%
new_df
# Out:
#                    Rape 16  Dowry Deaths 16  \
# ST
# Andhra Pradesh         994              193
# Arunachal Pradesh       92                1
# Assam                 1779              157
# Bihar                 1008              987
# Chhattisgarh          1626               84
# Goa                     61                2
# Gujarat                982               12
# Haryana               1187              260
# Himachal Pradesh       252                3
# Jammu & Kashmir        256                6
# Jharkhand             1109              278
# Karnataka             1655              234
# Kerala                1656               25
# Madhya Pradesh        4882              629
# Maharashtra           4189              248
# Manipur                 55                0
# Meghalaya              190                0
# Mizoram                 23                0
# Nagaland                26                1
# Odisha                1983              397
# ...

# %%
new_df
# Out:
#                    Rape 16  Dowry Deaths 16  \
# ST
# Andhra Pradesh         994              193
# Arunachal Pradesh       92                1
# Assam                 1779              157
# Bihar                 1008              987
# Chhattisgarh          1626               84
# Goa                     61                2
# Gujarat                982               12
# Haryana               1187              260
# Himachal Pradesh       252                3
# Jammu & Kashmir        256                6
# Jharkhand             1109              278
# Karnataka             1655              234
# Kerala                1656               25
# Madhya Pradesh        4882              629
# Maharashtra           4189              248
# Manipur                 55                0
# Meghalaya              190                0
# Mizoram                 23                0
# Nagaland                26                1
# Odisha                1983              397
# ...

# %%
new_df.to_csv("2016-2018 MAJOR CRIMES")
