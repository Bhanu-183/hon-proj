# %%
import pandas as pd

# %%
df_2015=pd.read_csv("2015.csv")

# %%
df_2015
# Out:
#           State/ UT                 Sl. No.     District/ Area    Year   Rape  \
# 0    Andhra Pradesh                       1          Anantapur  2015.0   32.0
# 1    Andhra Pradesh                       2           Chittoor  2015.0   31.0
# 2    Andhra Pradesh                       3           Cuddapah  2015.0   34.0
# 3    Andhra Pradesh                       4      East Godavari  2015.0  104.0
# 4    Andhra Pradesh                       5   Guntakal Railway  2015.0    1.0
# ..              ...                     ...                ...     ...    ...
# 848     Lakshadweep                       2  Total District(s)  2015.0    0.0
# 849      Puducherry                       1           Karaikal  2015.0    0.0
# 850      Puducherry                       2         Puducherry  2015.0    3.0
# 851      Puducherry                       3  Total District(s)  2015.0    3.0
# 852      Puducherry  Source: Crime in India                NaN     NaN    NaN
#
# ...

# %%
df_2015=df_2015[df_2015['District/ Area']=="Total District(s)"]

# %%
df_2015
# Out:
#              State/ UT Sl. No.     District/ Area    Year    Rape  \
# 20      Andhra Pradesh      21  Total District(s)  2015.0  1027.0
# 41   Arunachal Pradesh      21  Total District(s)  2015.0    71.0
# 80               Assam      39  Total District(s)  2015.0  1733.0
# 127              Bihar      47  Total District(s)  2015.0  1041.0
# 156       Chhattisgarh      29  Total District(s)  2015.0  1560.0
# 160                Goa       4  Total District(s)  2015.0    86.0
# 202            Gujarat      42  Total District(s)  2015.0   503.0
# 227            Haryana      25  Total District(s)  2015.0  1070.0
# 243   Himachal Pradesh      16  Total District(s)  2015.0   244.0
# 274    Jammu & Kashmir      31  Total District(s)  2015.0   296.0
# 301          Jharkhand      27  Total District(s)  2015.0  1053.0
# 338          Karnataka      37  Total District(s)  2015.0   589.0
# 360             Kerala      22  Total District(s)  2015.0  1256.0
# ...

# %%
final_df=pd.read_csv('2016-2018 MAJOR CRIMES')

# %%
final_df
# Out:
#                    ST  Rape 16  Dowry Deaths 16  \
# 0      Andhra Pradesh      994              193
# 1   Arunachal Pradesh       92                1
# 2               Assam     1779              157
# 3               Bihar     1008              987
# 4        Chhattisgarh     1626               84
# 5                 Goa       61                2
# 6             Gujarat      982               12
# 7             Haryana     1187              260
# 8    Himachal Pradesh      252                3
# 9     Jammu & Kashmir      256                6
# 10          Jharkhand     1109              278
# 11          Karnataka     1655              234
# 12             Kerala     1656               25
# 13     Madhya Pradesh     4882              629
# 14        Maharashtra     4189              248
# 15            Manipur       55                0
# 16          Meghalaya      190                0
# 17            Mizoram       23                0
# ...

# %%
df_2015=df_2015.set_index(final_df.index)

# %%
df_2015
# Out:
#             State/ UT Sl. No.     District/ Area    Year    Rape  \
# 0      Andhra Pradesh      21  Total District(s)  2015.0  1027.0
# 1   Arunachal Pradesh      21  Total District(s)  2015.0    71.0
# 2               Assam      39  Total District(s)  2015.0  1733.0
# 3               Bihar      47  Total District(s)  2015.0  1041.0
# 4        Chhattisgarh      29  Total District(s)  2015.0  1560.0
# 5                 Goa       4  Total District(s)  2015.0    86.0
# 6             Gujarat      42  Total District(s)  2015.0   503.0
# 7             Haryana      25  Total District(s)  2015.0  1070.0
# 8    Himachal Pradesh      16  Total District(s)  2015.0   244.0
# 9     Jammu & Kashmir      31  Total District(s)  2015.0   296.0
# 10          Jharkhand      27  Total District(s)  2015.0  1053.0
# 11          Karnataka      37  Total District(s)  2015.0   589.0
# 12             Kerala      22  Total District(s)  2015.0  1256.0
# ...

# %%
final_df['Rape 15']=df_2015['Rape']
final_df['Dowry Deaths 15']=df_2015['Dowry Deaths']
final_df['Assault on women with intent to outrage her modesty 15']=df_2015['Assault on Women with intent to outrage her Modesty_Total']
final_df['Cruelty By Husband or his relatives 15']=df_2015['Cruelty by Husband or his Relatives']
final_df['Insult to the modesty of women 15']=df_2015['Insult to the Modesty of Women_Total']
final_df['Kidnapping and Abduction 15']=df_2015['Kidnapping & Abduction_Total']

# %%
final_df
# Out:
#                    ST  Rape 16  Dowry Deaths 16  \
# 0      Andhra Pradesh      994              193
# 1   Arunachal Pradesh       92                1
# 2               Assam     1779              157
# 3               Bihar     1008              987
# 4        Chhattisgarh     1626               84
# 5                 Goa       61                2
# 6             Gujarat      982               12
# 7             Haryana     1187              260
# 8    Himachal Pradesh      252                3
# 9     Jammu & Kashmir      256                6
# 10          Jharkhand     1109              278
# 11          Karnataka     1655              234
# 12             Kerala     1656               25
# 13     Madhya Pradesh     4882              629
# 14        Maharashtra     4189              248
# 15            Manipur       55                0
# 16          Meghalaya      190                0
# 17            Mizoram       23                0
# ...

# %%
final_df.to_csv("2015-2018 MAJOR CRIMES.csv")
